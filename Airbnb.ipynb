# %%
import pandas as pd
import re
import numpy as np

data = pd.read_csv('Data_sets/listings_v1.csv')

# %%
data
# Out:
#              id                            listing_url       scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  20191207212953
# 1         20168     https://www.airbnb.com/rooms/20168  20191207212953
# 2         25428     https://www.airbnb.com/rooms/25428  20191207212953
# 3         27886     https://www.airbnb.com/rooms/27886  20191207212953
# 4         28871     https://www.airbnb.com/rooms/28871  20191207212953
# ...         ...                                    ...             ...
# 20020  40649791  https://www.airbnb.com/rooms/40649791  20191207212953
# 20021  40649918  https://www.airbnb.com/rooms/40649918  20191207212953
# 20022  40650044  https://www.airbnb.com/rooms/40650044  20191207212953
# 20023  40653547  https://www.airbnb.com/rooms/40653547  20191207212953
# 20024  40655209  https://www.airbnb.com/rooms/40655209  20191207212953
#
#       last_scraped                                               name  \
# 0       2019-12-08           Quiet Garden View Room & Super Fast WiFi
# 1       2019-12-08       Studio with private bathroom in the centre 1
# 2       2019-12-08    Lovely apt in City Centre (w.lift) near Jordaan
# 3       2019-12-08  Romantic, stylish B&B houseboat in canal district
# 4       2019-12-08                            Comfortable double room
# ...            ...                                                ...
# 20020   2019-12-08                  Amsterdam Deluxe Flat w/ Elevator
# 20021   2019-12-08                        Nice Apartment in Amsterdam
# 20022   2019-12-08         Beautiful place in the heart of Amsterdam!
# 20023   2019-12-08                      Family apartment for 5 people
# 20024   2019-12-08                                     cozy apartment
#
#                                                  summary  \
# 0               Quiet Garden View Room & Super Fast WiFi
# 1      17th century Dutch townhouse in the heart of t...
# 2                                                    NaN
# 3      Stylish and romantic houseboat on fantastic hi...
# 4                                                    NaN
# ...                                                  ...
# 20020  The Amsterdam Deluxe Flat is centrally located...
# 20021  Nice house suitable for a maximum of 4 people ...
# 20022                                                NaN
# 20023  Large apartment, 3 bedrooms, large living with...
# 20024                                                NaN
#
#                                                    space  \
# 0      I'm renting a bedroom (room overlooking the ga...
# 1      For those who like all facets of city life. In...
# 2      This nicely furnished, newly renovated apt  is...
# 3      For a romantic couple: A beautifully restored ...
# 4      In a monumental house right in the center of A...
# ...                                                  ...
# 20020  It's a light 70m2 apartment. With a king-size ...
# 20021                                                NaN
# 20022                                                NaN
# 20023                                                NaN
# 20024                                                NaN
#
#                                              description experiences_offered  \
# 0      Quiet Garden View Room & Super Fast WiFi I'm r...                none
# 1      17th century Dutch townhouse in the heart of t...                none
# 2      This nicely furnished, newly renovated apt  is...                none
# 3      Stylish and romantic houseboat on fantastic hi...                none
# 4      In a monumental house right in the center of A...                none
# ...                                                  ...                 ...
# 20020  The Amsterdam Deluxe Flat is centrally located...                none
# 20021  Nice house suitable for a maximum of 4 people ...                none
# 20022                                                NaN                none
# 20023  Large apartment, 3 bedrooms, large living with...                none
# 20024                                                NaN                none
#
#                                    neighborhood_overview  ...  \
# 0      Indische Buurt ("Indies Neighborhood") is a ne...  ...
# 1      Located just in between famous central canals....  ...
# 2                                                    NaN  ...
# 3             Central, quiet, safe, clean and beautiful.  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 20020  This apartment is in the vibrant area called A...  ...
# 20021                                                NaN  ...
# 20022                                                NaN  ...
# 20023  The apartment is located at the end of hopping...  ...
# 20024                                                NaN  ...
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                    t                        f  strict_14_with_grace_period
# 1                    f                        f  strict_14_with_grace_period
# 2                    f                        f  strict_14_with_grace_period
# 3                    t                        f  strict_14_with_grace_period
# 4                    f                        f                     moderate
# ...                ...                      ...                          ...
# 20020                f                        f                     moderate
# 20021                t                        f                     flexible
# 20022                t                        f                     flexible
# 20023                f                        f                     moderate
# 20024                f                        f                     moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 20020                             f                                f
# 20021                             f                                f
# 20022                             f                                f
# 20023                             f                                f
# 20024                             f                                f
#
#        calculated_host_listings_count  \
# 0                                   1
# 1                                   2
# 2                                   2
# 3                                   1
# 4                                   3
# ...                               ...
# 20020                               1
# 20021                               1
# 20022                               2
# 20023                               2
# 20024                               1
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                0
# 2                                                2
# 3                                                0
# 4                                                0
# ...                                            ...
# 20020                                            1
# 20021                                            1
# 20022                                            0
# 20023                                            2
# 20024                                            1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                2
# 2                                                0
# 3                                                1
# 4                                                3
# ...                                            ...
# 20020                                            0
# 20021                                            0
# 20022                                            2
# 20023                                            0
# 20024                                            0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               2.13
# 1                                                0               2.57
# 2                                                0               0.13
# 3                                                0               2.14
# 4                                                0               2.81
# ...                                            ...                ...
# 20020                                            0                NaN
# 20021                                            0                NaN
# 20022                                            0                NaN
# 20023                                            0                NaN
# 20024                                            0                NaN
#
# [20025 rows x 106 columns]

# %%
# checking the shape of the dataframe

data.shape
# Out:
# (20025, 106)

# %%
# printing the columns of the dataframe

print(list(data.columns))
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'license', 'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
# checking when the data was obtained

data['last_scraped'].value_counts()
# Out:
# 2019-12-08    18137
# 2019-12-07     1888
# Name: last_scraped, dtype: int64

# %%
# checking the datatypes of the columns

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20025 entries, 0 to 20024
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(23), int64(21), object(62)
# memory usage: 16.2+ MB

# %%
# creating a new dataframe with the relevant columns

data2 = data[['id', 'scrape_id', 'last_scraped', 'city', 'zipcode', 'country', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'square_feet', 'price']]

# %%
# Data cleaning: checking missing values

null_cols = data2.isnull().sum()
null_cols[null_cols > 0]
# Out:
# city               5
# zipcode          827
# square_feet    19662
# dtype: int64

# %%
# We are going to drop the column of the square feet because 98% of the values are missing.
# So, instead of using the price per square meter, we are going to use the price per number of accommodates

data2 = data2.drop('square_feet', axis=1)

# %%
# removing the $ symbol from the price column in data2

data2[['price']] = data2.price.apply(lambda x: x.replace('$',''))
data2[['price']] = data2.price.apply(lambda x: x.replace(',',''))

# %%
# checking the data types of each column

data2.dtypes
# Out:
# id                 int64
# scrape_id          int64
# last_scraped      object
# city              object
# zipcode           object
# country           object
# latitude         float64
# longitude        float64
# property_type     object
# room_type         object
# accommodates       int64
# price             object
# dtype: object

# %%
# convert price from object to float64

data2['price'] = data2['price'].astype('float64')

# %%
# checking the data types of each column

data2.dtypes
# Out:
# id                 int64
# scrape_id          int64
# last_scraped      object
# city              object
# zipcode           object
# country           object
# latitude         float64
# longitude        float64
# property_type     object
# room_type         object
# accommodates       int64
# price            float64
# dtype: object

# %%
# changing the column name of price to price_USD

data2 = data2.rename(columns = {'price': 'price_USD'})

# %%
# adding two new columns: price in euros and price in euros per number of accommodates

Exchange_rate_USD_Eu = 0.895667

data2['price_€'] = data2['price_USD']*Exchange_rate_USD_Eu

data2['price_€_accommodates'] = data2['price_€']/data2['accommodates']

# %%
# checking for low variance columns

low_variance = []

for col in data2._get_numeric_data():
    minimum = min(data2[col])
    ninety_perc = np.percentile(data2[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)

print(low_variance)
# Out:
# ['scrape_id']

# %%
# At least 90% of the values in scrape_id are the same so we are going to remove them from our data set

data2 = data2.drop('scrape_id', axis=1)

# %%
# we are counting the number of values within the column city. 
# we are going to just analyse the data from the value "Amsterdam" because it represents 98% of the values

data2['city'].value_counts()
data3 = data2.loc[data2['city'].isin(['Amsterdam'])]
data3
# Out:
#              id last_scraped       city  zipcode      country  latitude  \
# 0          2818   2019-12-08  Amsterdam      NaN  Netherlands  52.36575
# 1         20168   2019-12-08  Amsterdam     1017  Netherlands  52.36509
# 2         25428   2019-12-08  Amsterdam     1016  Netherlands  52.37297
# 3         27886   2019-12-08  Amsterdam     1013  Netherlands  52.38673
# 4         28871   2019-12-08  Amsterdam     1017  Netherlands  52.36719
# ...         ...          ...        ...      ...          ...       ...
# 20020  40649791   2019-12-08  Amsterdam  1098 XB  Netherlands  52.35696
# 20021  40649918   2019-12-08  Amsterdam  1064 VZ  Netherlands  52.37556
# 20022  40650044   2019-12-08  Amsterdam  1012 JW  Netherlands  52.37355
# 20023  40653547   2019-12-08  Amsterdam  1107 EB  Netherlands  52.29548
# 20024  40655209   2019-12-08  Amsterdam  1102 RN  Netherlands  52.31949
#
#        longitude      property_type        room_type  accommodates  price_USD  \
# 0        4.94142          Apartment     Private room             2       59.0
# 1        4.89354          Townhouse     Private room             2       80.0
# 2        4.88339          Apartment  Entire home/apt             3      125.0
# 3        4.89208          Houseboat     Private room             2      155.0
# 4        4.89092          Apartment     Private room             2       75.0
# ...          ...                ...              ...           ...        ...
# 20020    4.94521          Apartment  Entire home/apt             3      137.0
# 20021    4.81353              House  Entire home/apt             4      135.0
# 20022    4.89435  Bed and breakfast     Private room             2       60.0
# 20023    4.97723          Apartment  Entire home/apt             5       95.0
# 20024    4.94985              House  Entire home/apt             2      110.0
#
#           price_€  price_€_accommodates
# 0       52.844353             26.422176
# 1       71.653360             35.826680
# 2      111.958375             37.319458
# 3      138.828385             69.414192
# 4       67.175025             33.587513
# ...           ...                   ...
# 20020  122.706379             40.902126
# 20021  120.915045             30.228761
# 20022   53.740020             26.870010
# 20023   85.088365             17.017673
# 20024   98.523370             49.261685
#
# [19723 rows x 13 columns]

# %%
stats = data3.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                         count          mean           std         min  \
# id                    19723.0  1.912751e+07  1.147403e+07  2818.00000
# latitude              19723.0  5.236587e+01  1.553520e-02    52.28954
# longitude             19723.0  4.888609e+00  3.530522e-02     4.76395
# accommodates          19723.0  2.868276e+00  1.303692e+00     1.00000
# price_USD             19723.0  1.637160e+02  1.988675e+02     0.00000
# price_€               19723.0  1.466350e+02  1.781191e+02     0.00000
# price_€_accommodates  19723.0  5.318789e+01  6.414563e+01     0.00000
#
#                                25%           50%           75%           max  \
# id                    9.619963e+06  1.842334e+07  2.792721e+07  4.065521e+07
# latitude              5.235539e+01  5.236483e+01  5.237539e+01  5.242471e+01
# longitude             4.863225e+00  4.886580e+00  4.908400e+00  5.027690e+00
# accommodates          2.000000e+00  2.000000e+00  4.000000e+00  1.800000e+01
# price_USD             9.900000e+01  1.340000e+02  1.850000e+02  9.000000e+03
# price_€               8.867103e+01  1.200194e+02  1.656984e+02  8.061003e+03
# price_€_accommodates  3.560276e+01  4.478335e+01  6.224886e+01  4.030501e+03
#
#                                IQR
# id                    1.830725e+07
# latitude              1.999500e-02
# longitude             4.517500e-02
# accommodates          2.000000e+00
# price_USD             8.600000e+01
# price_€               7.702736e+01
# price_€_accommodates  2.664609e+01

# %%
# checking for outliers

outliers = pd.DataFrame(columns=data3.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = data3[(data3[col] < lower) | 
                   (data3[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

# %%
list_outliers= outliers['Outlier'].tolist()
list(set(outliers))
# Out:
# ['Outlier',
#  'id',
#  'latitude',
#  'longitude',
#  'price_USD',
#  'price_€_accommodates',
#  'room_type',
#  'accommodates',
#  'property_type',
#  'last_scraped',
#  'city',
#  'price_€',
#  'zipcode',
#  'country']

# %%
# Finding and Removing Duplicates

before = len(data3)
data = data3.drop_duplicates()
after = len(data3)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
# checking missing values

null_cols = data3.isna().sum()
null_cols[null_cols > 0]
# Out:
# zipcode    818
# dtype: int64

# %%
# dropping rows with null values on zipcode

data3 = data3.dropna()

# %%
data4 = data3[data3['price_USD'] != 0]
data4.reset_index()
# Out:
#        index        id last_scraped       city  zipcode      country  \
# 0          1     20168   2019-12-08  Amsterdam     1017  Netherlands
# 1          2     25428   2019-12-08  Amsterdam     1016  Netherlands
# 2          3     27886   2019-12-08  Amsterdam     1013  Netherlands
# 3          4     28871   2019-12-08  Amsterdam     1017  Netherlands
# 4          5     29051   2019-12-08  Amsterdam     1017  Netherlands
# ...      ...       ...          ...        ...      ...          ...
# 18899  20020  40649791   2019-12-08  Amsterdam  1098 XB  Netherlands
# 18900  20021  40649918   2019-12-08  Amsterdam  1064 VZ  Netherlands
# 18901  20022  40650044   2019-12-08  Amsterdam  1012 JW  Netherlands
# 18902  20023  40653547   2019-12-08  Amsterdam  1107 EB  Netherlands
# 18903  20024  40655209   2019-12-08  Amsterdam  1102 RN  Netherlands
#
#        latitude  longitude      property_type        room_type  accommodates  \
# 0      52.36509    4.89354          Townhouse     Private room             2
# 1      52.37297    4.88339          Apartment  Entire home/apt             3
# 2      52.38673    4.89208          Houseboat     Private room             2
# 3      52.36719    4.89092          Apartment     Private room             2
# 4      52.36773    4.89151          Apartment     Private room             1
# ...         ...        ...                ...              ...           ...
# 18899  52.35696    4.94521          Apartment  Entire home/apt             3
# 18900  52.37556    4.81353              House  Entire home/apt             4
# 18901  52.37355    4.89435  Bed and breakfast     Private room             2
# 18902  52.29548    4.97723          Apartment  Entire home/apt             5
# 18903  52.31949    4.94985              House  Entire home/apt             2
#
#        price_USD     price_€  price_€_accommodates
# 0           80.0   71.653360             35.826680
# 1          125.0  111.958375             37.319458
# 2          155.0  138.828385             69.414192
# 3           75.0   67.175025             33.587513
# 4           55.0   49.261685             49.261685
# ...          ...         ...                   ...
# 18899      137.0  122.706379             40.902126
# 18900      135.0  120.915045             30.228761
# 18901       60.0   53.740020             26.870010
# 18902       95.0   85.088365             17.017673
# 18903      110.0   98.523370             49.261685
#
# [18904 rows x 14 columns]
