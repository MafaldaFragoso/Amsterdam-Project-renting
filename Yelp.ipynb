# %%
import json
import requests
import pandas as pd

# %%
api_key='yf-OSFRRj1BY5XMYy-YT4cNawIIlKPxQ8l3rJrvimW5kFXdHM7Gn9vvTgTKxnYyX8RW2A9TIPS5HHSFokAFmvXN_LgJv_pSBJVFnL7Xb-jdcZmAdLBKTDhUhCO1bXnYx'
headers = {'Authorization': 'Bearer %s' % api_key}

url='https://api.yelp.com/v3/businesses/search'

# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term': 'bars', 'location':'Amsterdam', 'limit': 50}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
parsed = json.loads(req.text)
businesses = parsed["businesses"]

# %%
data = pd.DataFrame(businesses)
data
# Out:
#                         id                                     alias  \
# 0   cG_CbBD5chV2-kk41yYDZg        proeflokaal-arendsnest-amsterdam-2
# 1   MmO0vQkJUxpywCGH5iZIJw                         door-74-amsterdam
# 2   4CvQlmnDiwC3ttrXcyaBVQ              cannibale-royale-amsterdam-2
# 3   bn7lFe1A5DWYLr9Ingkamg       flying-dutchmen-cocktails-amsterdam
# 4   FZaK4DuynsWxbpXW5F2SmQ                  brouwerij-t-ij-amsterdam
# 5   JMtMucaKaAwBOeaUos_P2w                          njoy-amsterdam-2
# 6   0HYdRBZnrrXE1FZG72viFg                     beer-temple-amsterdam
# 7   7ivAcIaMxU45fwPfB9S7ug                  bols-amsterdam-amsterdam
# 8   cLYanTVjbzWVRxGrDFfVdw                       skylounge-amsterdam
# 9   uwA2w6HH8Bq3IYcOOKT5DA                 pulitzers-bar-amsterdam-2
# 10  tUzDYRcqwZrNEiN3rLtgVA                tales-en-spirits-amsterdam
# 11  Y4KNFfdZFcV52D_Eh8nN9g                    smoking-bull-amsterdam
# 12  AqoRT7Ox-I31eK70e2MKTw                   the-waterhole-amsterdam
# ...

# %%
data.shape
# Out:
# (50, 16)
